# %% [markdown]
# <a href="https://colab.research.google.com/github/pawnzo90z/competitions/blob/master/hdfc_challange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/for_google_notebook/hdfc_challenge/DataSet/")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv("Train.csv")
df_test = pd.read_csv("Test.csv")
print(len(df_train),len(df_test))
print(df_train.head())
print(df_test.head())
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (746,835) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (700,731,740,752,761,789,811,820,829,841,850) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 17521 20442
#         Col1  Col2          Col3  ...  Col2395  Col2396  Col2397
# 0    RIGHGSN     1  1.086711e+04  ...     22.0     22.0      7.0
# 1  RIMHI5ZGP     0  2.584312e+05  ...     12.0     12.0     11.0
# 2  RIHOG1SZU     0  1.459355e+07  ...     21.0     21.0     16.0
# 3  RIHOLMQWU     0  6.727043e+05  ...    951.0    951.0    743.0
# 4  RIHO584ET     0 -1.218742e+06  ...   2205.0   2205.0   1831.0
#
# [5 rows x 2395 columns]
# ...

# %%
df_train.describe()
# Out:
#                Col2          Col3  ...       Col2396       Col2397
# count  17521.000000  1.752100e+04  ...  16347.000000  16335.000000
# mean       0.100508  3.158967e+04  ...     17.539977     10.359657
# std        0.300685  7.612897e+05  ...     24.685954     18.476447
# min        0.000000 -8.555719e+07  ...      0.000000      0.000000
# 25%        0.000000  2.742337e+03  ...      9.000000      5.000000
# 50%        0.000000  9.308060e+03  ...     13.000000      7.000000
# 75%        0.000000  3.053873e+04  ...     21.000000     12.000000
# max        1.000000  1.459355e+07  ...   2205.000000   1831.000000
#
# [8 rows x 2133 columns]

# %%
df_train.head()
# Out:
#         Col1  Col2          Col3  ...  Col2395  Col2396  Col2397
# 0    RIGHGSN     1  1.086711e+04  ...     22.0     22.0      7.0
# 1  RIMHI5ZGP     0  2.584312e+05  ...     12.0     12.0     11.0
# 2  RIHOG1SZU     0  1.459355e+07  ...     21.0     21.0     16.0
# 3  RIHOLMQWU     0  6.727043e+05  ...    951.0    951.0    743.0
# 4  RIHO584ET     0 -1.218742e+06  ...   2205.0   2205.0   1831.0
#
# [5 rows x 2395 columns]

# %%
#df_train.drop(list_of_drop_columns,axis=1,inplace = True)
#df_test.drop(list_of_drop_columns,axis=1,inplace = True)

# %%
df_train.shape
# Out:
# (17521, 2134)

# %%
df = pd.concat([df_train, df_test],axis = 0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.drop(["Col1","Col2"],axis = 1,inplace = True)

# %%
df.shape
# Out:
# (37963, 2393)

# %%
list_of_drop_columns = []
for i in df:
  a = len(df[i])
  b = df[i].isnull().sum()
  if b != 0 and (b/a)*100 >= 30:
    list_of_drop_columns.append(i)
print((list_of_drop_columns))
# Out:
# ['Col100', 'Col101', 'Col102', 'Col103', 'Col104', 'Col105', 'Col109', 'Col111', 'Col112', 'Col113', 'Col114', 'Col115', 'Col116', 'Col117', 'Col118', 'Col119', 'Col138', 'Col139', 'Col140', 'Col141', 'Col142', 'Col143', 'Col144', 'Col145', 'Col146', 'Col147', 'Col148', 'Col149', 'Col150', 'Col151', 'Col152', 'Col153', 'Col154', 'Col155', 'Col156', 'Col157', 'Col158', 'Col159', 'Col171', 'Col185', 'Col19', 'Col20', 'Col249', 'Col251', 'Col252', 'Col253', 'Col254', 'Col259', 'Col261', 'Col262', 'Col263', 'Col265', 'Col266', 'Col271', 'Col273', 'Col274', 'Col275', 'Col276', 'Col28', 'Col281', 'Col283', 'Col284', 'Col285', 'Col287', 'Col288', 'Col334', 'Col335', 'Col336', 'Col338', 'Col339', 'Col340', 'Col341', 'Col342', 'Col343', 'Col344', 'Col347', 'Col348', 'Col351', 'Col352', 'Col353', 'Col355', 'Col356', 'Col357', 'Col359', 'Col360', 'Col361', 'Col362', 'Col363', 'Col364', 'Col365', 'Col368', 'Col369', 'Col37', 'Col372', 'Col373', 'Col374', 'Col375', 'Col376', 'Col38', 'Col382', 'C
# ...

# %%
df.drop(list_of_drop_columns,axis=1,inplace = True)

# %%
df.shape[0]
# Out:
# 37963

# %%
print(df["Col110"].value_counts())
# Out:
# 0.0    8266
# 1.0    6428
# 2.0    5626
# 3.0    4196
# 4.0    2946
# Name: Col110, dtype: int64

# %%
for i in df:
  #a = len(df[i])
  if df[i].isnull().sum() > 0:
    #print(df[i].value_counts())
    print(df[i].unique(),"------------------------------",i,len(df[i].unique()))

    #if df[c].dtype == "int64":
    #  df[c].fillna(df[c].mode()[0], inplace=True)
    #elif df[c].dtype == "float64":

# %%
df.head()
# Out:
#           Col10  Col100  Col1000  Col1001  ...  Col996  Col997  Col998  Col999
# 1  1.666974e+05     0.0        3        1  ...       0       0       1       0
# 2  6.906324e+06     1.0        4        0  ...       3       1       4       0
# 3  4.236612e+05     1.0        4        0  ...       0       0       4       0
# 4  5.446532e+06     1.0        4        0  ...       3       0       0       0
# 5  2.116667e+06     0.0        2        1  ...       2       1       0       0
#
# [5 rows x 2393 columns]

# %%
for c in df.columns:
  if df[c].dtype == "int64":
    df[c].fillna(df[c].mode()[0], inplace=True)
  elif df[c].dtype == "float64":
    df[c].fillna(df[c].mean(), inplace=True)
  else:
    print(df[c].dtype,c)
    df = df[df[c] != "-"]
    df[c] = pd.to_numeric(df[c])
    df[c].fillna(df[c].mode()[0], inplace=True)
    #df[c] = df[c].astype(int)

# %%
count = 0
for i in df:
  if len(df[i].unique())<=15:
    #print(df[i].mode())
    df[i].fillna(df[i].mode()[0],inplace = True)
    count+=1
count
# Out:
# 1569

# %%
count = 0
for i in df:
  if len(df[i].unique())>15:
    try:
      df[i].fillna((df[i].mean()),inplace = True)
      count+=1
    except:
      print(i)
    
count
# Out:
# 824

# %%
for i in df:
  if df[i].isnull().sum() > 0:
    print(i)
    #df[c].fillna(df[c].mode()[0], inplace=True)

# %%
df["Col108"].tail()
# Out:
# 20437    2.000000
# 20438    1.000000
# 20439    2.000000
# 20440    0.000000
# 20441    1.306131
# Name: Col108, dtype: float64

# %%
import numpy as np

# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Drop features 
df.drop(to_drop, axis=1,inplace = True)

# %%
temp = df

# %%
temp.head()
# Out:
#           Col10  Col1000  Col1001  Col1002  ...  Col936  Col94  Col96  Col98
# 0  2.871509e+04        2        3        2  ...       3    0.0    0.0    0.0
# 1  1.666974e+05        3        1        0  ...       3    0.0    0.0    0.0
# 2  6.906324e+06        4        0        0  ...       2    1.0    1.0    1.0
# 3  4.236612e+05        4        0        0  ...       3    0.0    0.0    0.0
# 4  5.446532e+06        4        0        0  ...       3    2.0    2.0    2.0
#
# [5 rows x 651 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df.head()
# Out:
#           Col10  Col1000  Col1001  Col1002  ...  Col996  Col997  Col998  Col999
# 0  2.871509e+04        2        3        2  ...       2       1       2       3
# 1  1.666974e+05        3        1        0  ...       0       0       1       0
# 2  6.906324e+06        4        0        0  ...       3       1       4       0
# 3  4.236612e+05        4        0        0  ...       0       0       4       0
# 4  5.446532e+06        4        0        0  ...       3       0       0       0
#
# [5 rows x 2120 columns]

# %%
#scaler=MinMaxScaler(feature_range=[0, 1])
#data_rescaled = scaler.fit_transform(df)
scaler=StandardScaler()
data_rescaled = scaler.fit(df)

# %%
scaled_data=scaler.transform(df)

# %%
scaled_data
# Out:
# array([[-7.91642828e-03,  9.34084208e-02,  1.81791732e+00, ...,
#         -1.11751480e+00, -1.29183397e+00, -1.44216410e+00],
#        [ 3.90257663e-01,  8.98965867e-01, -2.51859255e-01, ...,
#         -1.11751480e+00, -1.29183397e+00, -1.44216410e+00],
#        [ 1.98387286e+01,  1.70452331e+00, -1.28674754e+00, ...,
#         -3.30220450e-01, -5.26475341e-01, -6.78737633e-01],
#        ...,
#        [ 1.36035438e-01, -7.12149025e-01,  7.83029034e-01, ...,
#          4.57073898e-01,  2.38883292e-01,  8.46888340e-02],
#        [-3.73988472e-02, -7.12149025e-01, -2.51859255e-01, ...,
#         -1.11751480e+00, -1.29183397e+00, -1.44216410e+00],
#        [ 7.64562257e+01,  8.98965867e-01, -2.51859255e-01, ...,
#         -1.74814462e-16,  1.69943755e-16,  1.69514728e-16]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=150)
pca.fit(scaled_data)
x_pca=pca.transform(scaled_data)




#Plotting the Cumulative Summation of the Explained Variance

# %%
scaled_data.shape
# Out:
# (37963, 2120)

# %%
x_pca.shape
# Out:
# (37963, 150)

# %%
scaled_data
# Out:
# array([[-7.91642828e-03,  9.34084208e-02,  1.81791732e+00, ...,
#         -8.23619347e-01, -8.55433991e-01, -8.49128174e-01],
#        [ 3.90257663e-01,  8.98965867e-01, -2.51859255e-01, ...,
#         -8.23619347e-01, -8.55433991e-01, -8.49128174e-01],
#        [ 1.98387286e+01,  1.70452331e+00, -1.28674754e+00, ...,
#         -1.03545162e-01, -1.85960078e-01, -2.11332818e-01],
#        ...,
#        [ 1.36035438e-01, -7.12149025e-01,  7.83029034e-01, ...,
#          6.16529024e-01,  4.83513836e-01,  4.26462537e-01],
#        [-3.73988472e-02, -7.12149025e-01, -2.51859255e-01, ...,
#         -8.23619347e-01, -8.55433991e-01, -8.49128174e-01],
#        [ 7.64562257e+01,  8.98965867e-01, -2.51859255e-01, ...,
#         -8.23619347e-01, -8.55433991e-01, -8.49128174e-01]])

# %%
x_pca
# Out:
# array([[ -0.73091506, -13.68324613,  -0.91967748, ...,   0.83450738,
#           0.98125998,   1.68374708],
#        [-21.56047542,   8.10332505,  -3.33036861, ...,  -1.84361299,
#          -1.17478983,  -0.27276919],
#        [ 11.04989857,  20.1006318 ,  -6.9107975 , ...,   2.65508884,
#           1.04084967,   3.04298373],
#        ...,
#        [  4.43929755, -10.02118104,  -1.67070423, ...,  -0.81500224,
#          -1.12567641,  -1.05847487],
#        [-22.36932422,  12.16223268,  -9.61321261, ...,  -1.05936288,
#          -0.87767591,   0.72185187],
#        [ -7.10272967,  15.0248835 ,  26.03820111, ...,   2.25264639,
#           7.82681714,  -1.02648746]])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('HDFC')
plt.show()

# %%
#pca = PCA(n_components=100)
#dataset = pca.fit_transform(data_rescaled)

# %%
#dataset.shape
#new_df = pd.DataFrame(x_pca)
new_df = df

# %%
new_df.head()
# Out:
#           Col10  Col100  Col1000  Col1001  ...  Col996  Col997  Col998  Col999
# 0  2.871509e+04     0.0        2        3  ...       2       1       2       3
# 1  1.666974e+05     0.0        3        1  ...       0       0       1       0
# 2  6.906324e+06     1.0        4        0  ...       3       1       4       0
# 3  4.236612e+05     1.0        4        0  ...       0       0       4       0
# 4  5.446532e+06     1.0        4        0  ...       3       0       0       0
#
# [5 rows x 2393 columns]

# %%
train_for_model = new_df.iloc[:17521]
train_for_model.head()
# Out:
#           Col10  Col100  Col1000  Col1001  ...  Col996  Col997  Col998  Col999
# 0  2.871509e+04     0.0        2        3  ...       2       1       2       3
# 1  1.666974e+05     0.0        3        1  ...       0       0       1       0
# 2  6.906324e+06     1.0        4        0  ...       3       1       4       0
# 3  4.236612e+05     1.0        4        0  ...       0       0       4       0
# 4  5.446532e+06     1.0        4        0  ...       3       0       0       0
#
# [5 rows x 2393 columns]

# %%
test_for_model = new_df.iloc[17522:]
test_for_model.head()
# Out:
#              Col10    Col100  Col1000  Col1001  ...  Col996  Col997  Col998  Col999
# 158     747.114235  1.328292        0        0  ...       3       1       0       0
# 159  187258.710500  2.000000        2        3  ...       0       0       0       0
# 160    4182.991601  5.000000        2        2  ...       3       2       2       2
# 161   19079.444550  5.000000        3        3  ...       2       2       3       3
# 162   59162.835990  1.328292        3        1  ...       0       0       3       1
#
# [5 rows x 2393 columns]

# %%
a = df_train["Col2"]
a.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Col2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-5159a0594f16> in <module>()
#       1 a = df_train["Col2"]
# ...

# %%
train_for_model = pd.concat([train_for_model,a],axis=1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-121-51bbefafc019> in <module>()
# ----> 1 train_for_model = pd.concat([train_for_model,a],axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     379         self.copy = copy
#     380
# --> 381         self.new_axes = self._get_new_axes()
#     382
# ...

# %%
y = train_for_model["Col2"]
X = train_for_model.drop(["Col2"],axis=1)

# %%
y.value_counts()
# Out:
# 0    15760
# 1     1761
# Name: Col2, dtype: int64

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_sample(X,y)

# %%
len(y_train_res)

# %%
from sklearn.model_selection import train_test_split
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X, y,test_size=0.3)

# %%
i = 128
from sklearn.ensemble import RandomForestClassifier
for i in range(5):
  i = i +128
  rfc = RandomForestClassifier(n_estimators=i,class_weight={0:25,1:6})
  rfc = rfc.fit(X_train_new,y_train_new)
  pred_train=rfc.predict(X_test_new)
  a = (pd.crosstab(y_test_new,pred_train))
  accuracy2= float((a[1][1]+a[0][0])/len(y_test_new))
  error2=float((a[1][0]+a[0][1])/len(y_test_new))
  print( ("Accuracy is ")+ str(accuracy2))
  print (("error is ")+ str(error2))

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=128,class_weight={0:14,1:3})
rfc = rfc.fit(X_train_new,y_train_new)
pred_train=rfc.predict(X_test_new)
a = (pd.crosstab(y_test_new,pred_train))
accuracy2= float((a[1][1]+a[0][0])/len(y_test_new))
error2=float((a[1][0]+a[0][1])/len(y_test_new))
print( ("Accuracy is ")+ str(accuracy2))
print (("error is ")+ str(error2))
# Out:
# Accuracy is 0.9027962716378163
# error is 0.09720372836218376

# %%
test_for_model.head()
# Out:
#               0          1         2   ...        47         48         49
# 17522  18.478696  12.388565  7.027576  ... -3.454359   1.017085   5.674387
# 17523   2.360029   7.190505  0.299653  ... -2.040836   1.179786   2.246588
# 17524 -15.478359   5.065693 -1.848205  ... -3.091978  -3.523858   4.415664
# 17525 -14.217634   3.487342  7.221510  ... -1.151189   0.211726   1.077188
# 17526   3.867171  11.343338  3.768522  ...  4.998752  19.583364 -34.883702
#
# [5 rows x 50 columns]

# %%
#test_for_model.drop(["Col1"],inplace = True,axis = 1)
test_pred = rfc.predict(test_for_model)

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
data_dmatrix = xgb.DMatrix(data=train_for_model,label=y_train_res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-05ebb2950a69> in <module>()
# ----> 1 data_dmatrix = xgb.DMatrix(data=X_train_res,label=y_train_res)
#
# NameError: name 'X_train_res' is not defined

# %%
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X, y,test_size=0.2,random_state=1)

# %%
xg_reg = xgb.XGBClassifier(objective ='reg:logistic', colsample_bytree = 0.2, learning_rate = 0.1,max_depth = 3, alpha = 10, n_estimators =100)

# %%
xg_reg = xg_reg.fit(X_train_new,y_train_new)

# %%
pred_train = xg_reg.predict(X_test_new)
a = (pd.crosstab(y_test_new,pred_train))
accuracy2= float((a[1][1]+a[0][0])/len(y_test_new))
error2=float((a[1][0]+a[0][1])/len(y_test_new))
print( ("Accuracy is ")+ str(accuracy2))
print (("error is ")+ str(error2))
# Out:
# Accuracy is 0.9004279600570614
# error is 0.09957203994293866

# %%
pred_train
# Out:
# array([0., 1., 1., ..., 1., 1., 1.])

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=100)
clf.fit(X_train_new,y_train_new)
pred_train = clf.predict(X_test_new)
a = (pd.crosstab(y_test_new,pred_train))
accuracy2= float((a[1][1]+a[0][0])/len(y_test_new))
error2=float((a[1][0]+a[0][1])/len(y_test_new))
print( ("Accuracy is ")+ str(accuracy2))
print (("error is ")+ str(error2))
# Out:
# Accuracy is 0.8987161198288159
# error is 0.10128388017118402

# %%
X_test_new.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-c34573e1c781> in <module>()
# ----> 1 X_test_new.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
test_pred = xg_reg.predict(test_for_model)

# %%
joinme = pd.DataFrame(test_pred,columns = ["Col2"])

# %%
df1 = pd.concat([df_test["Col1"],joinme["Col2"]],axis = 1)

# %%
df1.head()
# Out:
#         Col1  Col2
# 0  RIGD58ZWD   0.0
# 1  RIH660YDS   0.0
# 2  RIH660Q96   0.0
# 3  RIYDO15W1   0.0
# 4  RIYBGC1ZD   1.0

# %%
df1.to_csv("submit.csv", index=False)
